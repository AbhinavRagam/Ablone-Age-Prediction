# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\abhin\machine learning\term 1 project\ablone\abalone_train.csv")
df
# Out:
#         Id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0     3141   I   0.180     0.135   0.080        0.0330          0.0145
# 1     3521   I   0.215     0.150   0.055        0.0410          0.0150
# 2      883   M   0.660     0.530   0.170        1.3905          0.5905
# 3     3627   M   0.715     0.525   0.200        1.8900          0.9500
# 4     2106   M   0.595     0.455   0.155        1.0410          0.4160
# ...    ...  ..     ...       ...     ...           ...             ...
# 3336  1033   M   0.650     0.525   0.185        1.6220          0.6645
# 3337  3264   F   0.655     0.500   0.140        1.1705          0.5405
# 3338  1653   M   0.595     0.450   0.145        0.9590          0.4630
# 3339  2607   F   0.625     0.490   0.165        1.1270          0.4770
# 3340  2732   I   0.410     0.325   0.110        0.3260          0.1325
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.0070        0.0100      5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3341 entries, 0 to 3340
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              3341 non-null   int64
#  1   Sex             3341 non-null   object
#  2   Length          3341 non-null   float64
#  3   Diameter        3341 non-null   float64
#  4   Height          3341 non-null   float64
#  5   Whole_weight    3341 non-null   float64
#  6   Shucked_weight  3341 non-null   float64
#  7   Viscera_weight  3341 non-null   float64
#  8   Shell_weight    3341 non-null   float64
#  9   Rings           3341 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 261.1+ KB

# %%
df.describe()
# Out:
#                 Id       Length     Diameter       Height  Whole_weight  \
# count  3341.000000  3341.000000  3341.000000  3341.000000   3341.000000
# mean   2085.442083     0.525887     0.409463     0.140129      0.838176
# std    1197.721846     0.119759     0.098895     0.042623      0.493789
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%    1055.000000     0.450000     0.350000     0.115000      0.444500
# 50%    2086.000000     0.545000     0.425000     0.145000      0.810000
# 75%    3114.000000     0.620000     0.485000     0.165000      1.168500
# max    4175.000000     0.815000     0.650000     1.130000      2.779500
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     3341.000000     3341.000000   3341.000000  3341.000000
# mean         0.363600        0.182507      0.241385     9.958396
# std          0.224156        0.110439      0.139828     3.205591
# ...

# %% [markdown]
# # Checking for Outliers in Height

# %%
df['Height'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Height=np.percentile(df['Height'],25)
Q3_Height=np.percentile(df['Height'],75)
Q1_Height,Q3_Height
# Out:
# (0.115, 0.165)

# %%
IQR_Height=Q3_Height-Q1_Height
IQR_Height
# Out:
# 0.05

# %%
Upper_Height = Q3_Height+1.5*IQR_Height
Lower_Height = Q1_Height-1.5*IQR_Height
Upper_Height , Lower_Height
# Out:
# (0.24000000000000002, 0.039999999999999994)

# %%
df.loc[(df['Height']>0.24),'Height']=df['Height'].median()
df.loc[(df['Height']<0.039999),'Height']=df['Height'].median()

# %%
Q1_Height=np.percentile(df['Height'],25)
Q3_Height=np.percentile(df['Height'],75)
Q1_Height,Q3_Height
# Out:
# (0.115, 0.165)

# %%
IQR_Height=Q3_Height-Q1_Height
IQR_Height
# Out:
# 0.05

# %%
Upper_Height = Q3_Height+1.5*IQR_Height
Lower_Height = Q1_Height-1.5*IQR_Height
Upper_Height , Lower_Height
# Out:
# (0.24000000000000002, 0.039999999999999994)

# %%
df.loc[(df['Height']>0.24),'Height']=df['Height'].median()
df.loc[(df['Height']<0.039999),'Height']=df['Height'].median()

# %%
df['Height'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking for Outliers in Length

# %%
df['Length'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Length=np.percentile(df['Length'],25)
Q3_Length=np.percentile(df['Length'],75)
Q1_Length,Q3_Length
# Out:
# (0.45, 0.62)

# %%
IQR_Length=Q3_Length-Q1_Length
IQR_Length
# Out:
# 0.16999999999999998

# %%
Upper_Length = Q3_Length+1.5*IQR_Length
Lower_Length = Q1_Length-1.5*IQR_Length
Upper_Length , Lower_Length
# Out:
# (0.875, 0.195)

# %%
df.loc[(df['Length']>0.875),'Length']=df['Length'].median()
df.loc[(df['Length']<0.195),'Length']=df['Length'].median()

# %%
df['Length'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking for Outliers in Diameter

# %%
df['Diameter'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Diameter=np.percentile(df['Diameter'],25)
Q3_Diameter=np.percentile(df['Diameter'],75)
Q1_Diameter,Q3_Diameter
# Out:
# (0.35, 0.485)

# %%
IQR_Diameter=Q3_Diameter-Q1_Diameter
IQR_Diameter
# Out:
# 0.135

# %%
Upper_Diameter = Q3_Diameter+1.5*IQR_Diameter
Lower_Diameter = Q1_Diameter-1.5*IQR_Diameter
Upper_Diameter , Lower_Diameter
# Out:
# (0.6875, 0.14749999999999996)

# %%
df.loc[(df['Diameter']>0.6875),'Diameter']=df['Diameter'].median()
df.loc[(df['Diameter']<0.1474),'Diameter']=df['Diameter'].median()

# %%
df['Diameter'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking for Outliers in  Whole_weight

# %%
df['Whole_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Whole_weight=np.percentile(df['Whole_weight'],25)
Q3_Whole_weight=np.percentile(df['Whole_weight'],75)
Q1_Whole_weight,Q3_Whole_weight
# Out:
# (0.4445, 1.1685)

# %%
IQR_Whole_weight=Q3_Whole_weight-Q1_Whole_weight
IQR_Whole_weight
# Out:
# 0.7240000000000001

# %%
Upper_Whole_weight = Q3_Whole_weight+1.5*IQR_Whole_weight
Lower_Whole_weight = Q1_Whole_weight-1.5*IQR_Whole_weight
Upper_Whole_weight , Lower_Whole_weight
# Out:
# (2.2545, -0.6415000000000001)

# %%
df.loc[(df['Whole_weight']>2.2545),'Whole_weight']=df['Whole_weight'].median()
df.loc[(df['Whole_weight']<-0.6415),'Whole_weight']=df['Whole_weight'].median()

# %%
df['Whole_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Id', 'Sex', 'Length', 'Diameter', 'Height', 'Whole_weight',
#        'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# # Checking for Outliers in Shucked_weight

# %%
df['Shucked_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Shucked_weight=np.percentile(df['Shucked_weight'],25)
Q3_Shucked_weight=np.percentile(df['Shucked_weight'],75)
Q1_Shucked_weight,Q3_Shucked_weight
# Out:
# (0.188, 0.5095)

# %%
IQR_Shucked_weight=Q3_Shucked_weight-Q1_Shucked_weight
IQR_Shucked_weight
# Out:
# 0.32149999999999995

# %%
Upper_Shucked_weight = Q3_Shucked_weight+1.5*IQR_Shucked_weight
Lower_Shucked_weight = Q1_Shucked_weight-1.5*IQR_Shucked_weight
Upper_Shucked_weight , Lower_Shucked_weight
# Out:
# (0.9917499999999999, -0.29424999999999996)

# %%
df.loc[(df['Shucked_weight']>0.99174),'Shucked_weight']=df['Shucked_weight'].median()

# %%
df['Shucked_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking for Outliers in Viscera_weight

# %%
df['Viscera_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Viscera_weight=np.percentile(df['Viscera_weight'],25)
Q3_Viscera_weight=np.percentile(df['Viscera_weight'],75)
Q1_Viscera_weight,Q3_Viscera_weight
# Out:
# (0.0935, 0.2555)

# %%
IQR_Viscera_weight=Q3_Viscera_weight-Q1_Viscera_weight
IQR_Viscera_weight
# Out:
# 0.162

# %%
Upper_Viscera_weight = Q3_Viscera_weight+1.5*IQR_Viscera_weight
Lower_Viscera_weight = Q1_Viscera_weight-1.5*IQR_Viscera_weight
Upper_Viscera_weight , Lower_Viscera_weight
# Out:
# (0.4985, -0.1495)

# %%
df.loc[(df['Viscera_weight']>0.4985),'Viscera_weight']=df['Viscera_weight'].median()

# %%
df['Viscera_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking for Outliers in Shell_weight

# %%
df['Shell_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
Q1_Shell_weight=np.percentile(df['Shell_weight'],25)
Q3_Shell_weight=np.percentile(df['Shell_weight'],75)
Q1_Shell_weight,Q3_Shell_weight
# Out:
# (0.132, 0.33)

# %%
IQR_Shell_weight=Q3_Shell_weight-Q1_Shell_weight
IQR_Shell_weight
# Out:
# 0.198

# %%
Upper_Shell_weight = Q3_Shell_weight+1.5*IQR_Shell_weight
Lower_Shell_weight = Q1_Shell_weight-1.5*IQR_Shell_weight
Upper_Shell_weight , Lower_Shell_weight
# Out:
# (0.627, -0.16500000000000004)

# %%
df.loc[(df['Shell_weight']>0.627),'Shell_weight']=df['Shell_weight'].median()

# %%
df['Shell_weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 Id       Length     Diameter       Height  Whole_weight  \
# count  3341.000000  3341.000000  3341.000000  3341.000000   3341.000000
# mean   2085.442083     0.529313     0.412721     0.140317      0.827963
# std    1197.721846     0.114665     0.094241     0.037324      0.477051
# min       0.000000     0.195000     0.150000     0.040000      0.002000
# 25%    1055.000000     0.455000     0.350000     0.115000      0.444500
# 50%    2086.000000     0.545000     0.425000     0.145000      0.810000
# 75%    3114.000000     0.620000     0.485000     0.165000      1.156500
# max    4175.000000     0.815000     0.650000     0.240000      2.250000
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     3341.000000     3341.000000   3341.000000  3341.000000
# mean         0.354652        0.180284      0.236957     9.958396
# std          0.208284        0.106738      0.131951     3.205591
# ...

# %%
df.isna().sum().sort_values()
# Out:
# Id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
df.drop('Id',axis=1 , inplace=True)

# %%
df = pd.get_dummies(df, columns=['Sex'], drop_first=True)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  3341.000000  3341.000000  3341.000000   3341.000000     3341.000000
# mean      0.529313     0.412721     0.140317      0.827963        0.354652
# std       0.114665     0.094241     0.037324      0.477051        0.208284
# min       0.195000     0.150000     0.040000      0.002000        0.001000
# 25%       0.455000     0.350000     0.115000      0.444500        0.188000
# 50%       0.545000     0.425000     0.145000      0.810000        0.341500
# 75%       0.620000     0.485000     0.165000      1.156500        0.501500
# max       0.815000     0.650000     0.240000      2.250000        0.991500
#
#        Viscera_weight  Shell_weight        Rings        Sex_I        Sex_M
# count     3341.000000   3341.000000  3341.000000  3341.000000  3341.000000
# mean         0.180284      0.236957     9.958396     0.314576     0.368752
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
df.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.545     0.425   0.080        0.0330          0.0145          0.0070
# 1   0.215     0.150   0.055        0.0410          0.0150          0.0090
# 2   0.660     0.530   0.170        1.3905          0.5905          0.2120
# 3   0.715     0.525   0.200        1.8900          0.9500          0.4360
# 4   0.595     0.455   0.155        1.0410          0.4160          0.2105
#
#    Shell_weight  Rings  Sex_I  Sex_M
# 0        0.0100      5      1      0
# 1        0.0125      3      1      0
# 2        0.4530     15      0      1
# 3        0.4305     10      0      1
# 4        0.3650     14      0      1

# %%
feature_cols = ['Length','Diameter','Height','Whole_weight','Shucked_weight','Viscera_weight','Shell_weight','Sex_I','Sex_M']
X = df[feature_cols]
X.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.545     0.425   0.080        0.0330          0.0145          0.0070
# 1   0.215     0.150   0.055        0.0410          0.0150          0.0090
# 2   0.660     0.530   0.170        1.3905          0.5905          0.2120
# 3   0.715     0.525   0.200        1.8900          0.9500          0.4360
# 4   0.595     0.455   0.155        1.0410          0.4160          0.2105
#
#    Shell_weight  Sex_I  Sex_M
# 0        0.0100      1      0
# 1        0.0125      1      0
# 2        0.4530      0      1
# 3        0.4305      0      1
# 4        0.3650      0      1

# %%
y = df.Rings
y.head()
# Out:
# 0     5
# 1     3
# 2    15
# 3    10
# 4    14
# Name: Rings, dtype: int64

# %% [markdown]
# # Splitting the data for training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=90)

# %%
print('Train cases as below')
print('X_train shape: ',X_train.shape)
print('y_train shape: ',y_train.shape)
print('\nTest cases as below')
print('X_test shape: ',X_test.shape)
print('y_test shape: ',y_test.shape)
# Out:
# Train cases as below
# X_train shape:  (3006, 9)
# y_train shape:  (3006,)
#
# Test cases as below
# X_test shape:  (335, 9)
# y_test shape:  (335,)

# %% [markdown]
# # Scaling of Data

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X_train[feature_cols]  = sc.fit_transform(X_train[feature_cols])
X_test[feature_cols] = sc.transform(X_test[feature_cols])

# %%
df.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.545     0.425   0.080        0.0330          0.0145          0.0070
# 1   0.215     0.150   0.055        0.0410          0.0150          0.0090
# 2   0.660     0.530   0.170        1.3905          0.5905          0.2120
# 3   0.715     0.525   0.200        1.8900          0.9500          0.4360
# 4   0.595     0.455   0.155        1.0410          0.4160          0.2105
#
#    Shell_weight  Rings  Sex_I  Sex_M
# 0        0.0100      5      1      0
# 1        0.0125      3      1      0
# 2        0.4530     15      0      1
# 3        0.4305     10      0      1
# 4        0.3650     14      0      1

# %%
X_train.head()
# Out:
#         Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 2124  0.233871      0.20   0.150      0.098087        0.103988
# 347   0.798387      0.75   0.675      0.755560        0.832408
# 168   0.717742      0.76   0.625      0.528247        0.480061
# 2551  0.129032      0.10   0.175      0.037367        0.029783
# 602   0.758065      0.84   0.725      0.676157        0.702171
#
#       Viscera_weight  Shell_weight  Sex_I  Sex_M
# 2124        0.084337      0.085806    1.0    0.0
# 347         0.725904      0.647153    0.0    1.0
# 168         0.601406      0.558941    0.0    1.0
# 2551        0.037149      0.045710    1.0    0.0
# 602         0.606426      0.647153    0.0    0.0

# %%
X_train.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  3006.000000  3006.000000  3006.000000   3006.000000     3006.000000
# mean      0.538176     0.524458     0.501181      0.366728        0.356481
# std       0.185697     0.188852     0.187030      0.212452        0.210801
# min       0.000000     0.000000     0.000000      0.000000        0.000000
# 25%       0.419355     0.400000     0.375000      0.196008        0.187279
# 50%       0.564516     0.550000     0.525000      0.359431        0.343261
# 75%       0.677419     0.670000     0.625000      0.514513        0.505679
# max       1.000000     1.000000     1.000000      1.000000        1.000000
#
#        Viscera_weight  Shell_weight        Sex_I        Sex_M
# count     3006.000000   3006.000000  3006.000000  3006.000000
# mean         0.359757      0.377428     0.315369     0.367931
# std          0.214550      0.212696     0.464740     0.482323
# ...

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train) 

lr
# Out:
# LinearRegression()

# %%
print('Intercept:',lr.intercept_)    
print('Coefficients:',lr.coef_)
# Out:
# Intercept: 6.523464052090933
# Coefficients: [-1.97213902  2.46017126  4.61916699  5.25903565 -8.46871276 -1.88512394
#   7.9287334  -1.02308819  0.01973606]

# %%
y_pred_train = lr.predict(X_train)  

y_pred_test = lr.predict(X_test)

# %%
list(zip(y_test,y_pred_test))
# Out:
# [(12, 12.752932049235747),
#  (11, 11.411229883311066),
#  (9, 9.801966312142188),
#  (7, 6.598180248203902),
#  (10, 8.095567429236574),
#  (8, 9.462617282555803),
#  (11, 12.203076703040491),
#  (6, 6.937906954996673),
#  (11, 12.01527475042537),
#  (15, 13.401455439391203),
#  (8, 8.83587940316724),
#  (9, 11.150896361228341),
#  (20, 12.216101278971632),
#  (10, 11.365487869650117),
#  (18, 12.566053626011598),
#  (12, 11.262484351453445),
#  (8, 8.574387250546298),
#  (13, 10.236818262162078),
#  (4, 5.967685174502237),
#  (8, 9.93975426820196),
#  (6, 6.401245368529031),
#  (4, 6.969486217947535),
#  (9, 9.634247927445504),
#  (10, 11.594931645064396),
#  (9, 9.018955845917954),
#  (15, 12.354364446967676),
#  (10, 11.741108836765946),
#  (9, 11.751145773625),
#  (9, 10.982535421715028),
#  (11, 9.549050901695802),
#  (4, 6.8304683467963185),
#  (4, 6.2976049870145685),
#  (15, 10.712344018799223),
#  (11, 10.409611286036256),
#  (6, 6.891365495436968),
# ...

# %%
sns.regplot(y_test,y_pred_test)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error ,r2_score

MSE_train = mean_squared_error(y_train, y_pred_train)
MSE_test = mean_squared_error(y_test, y_pred_test)

print('MSE for training set is {}'.format(MSE_train))
print('MSE for test set is {}'.format(MSE_test))
# Out:
# MSE for training set is 5.875138668106897
# MSE for test set is 4.914317599850899

# %%
RMSE_train = np.sqrt( mean_squared_error(y_train, y_pred_train))
RMSE_test = np.sqrt(mean_squared_error(y_test, y_pred_test))

print('RMSE for training set is {}'.format(RMSE_train))
print('RMSE for test set is {}'.format(RMSE_test))
# Out:
# RMSE for training set is 2.423868533585701
# RMSE for test set is 2.2168260193012213

# %% [markdown]
# # Predicting on the Unknown Data

# %%
df_test = pd.read_csv(r"C:\Users\abhin\machine learning\term 1 project\ablone\abalone_test.csv")
df_test
# Out:
#        Id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0     668   M   0.550     0.425   0.155        0.9175          0.2775
# 1    1580   I   0.500     0.400   0.120        0.6160          0.2610
# 2    3784   M   0.620     0.480   0.155        1.2555          0.5270
# 3     463   I   0.220     0.165   0.055        0.0545          0.0215
# 4    2615   M   0.645     0.500   0.175        1.5105          0.6735
# ..    ...  ..     ...       ...     ...           ...             ...
# 831   575   F   0.610     0.475   0.140        1.1330          0.5275
# 832  3231   M   0.410     0.325   0.120        0.3745          0.1580
# 833  1084   I   0.445     0.345   0.105        0.4090          0.1675
# 834   290   M   0.540     0.435   0.180        0.9960          0.3835
# 835  2713   I   0.250     0.175   0.060        0.0635          0.0275
#
#      Viscera_weight  Shell_weight
# 0            0.2430        0.3350
# 1            0.1430        0.1935
# ...

# %%
df_test = pd.get_dummies(df_test, columns=['Sex'], drop_first=True)

# %%
df_test.head()
# Out:
#      Id  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0   668   0.550     0.425   0.155        0.9175          0.2775
# 1  1580   0.500     0.400   0.120        0.6160          0.2610
# 2  3784   0.620     0.480   0.155        1.2555          0.5270
# 3   463   0.220     0.165   0.055        0.0545          0.0215
# 4  2615   0.645     0.500   0.175        1.5105          0.6735
#
#    Viscera_weight  Shell_weight  Sex_I  Sex_M
# 0          0.2430        0.3350      0      1
# 1          0.1430        0.1935      1      0
# 2          0.3740        0.3175      0      1
# 3          0.0120        0.0200      1      0
# 4          0.3755        0.3775      0      1

# %%
df_test.drop('Id',axis=1 , inplace=True)

# %%
df_test2=df_test.loc[: , ['Length','Diameter','Height','Whole_weight','Shucked_weight','Viscera_weight','Shell_weight','Sex_I','Sex_M']]
df_test2
# Out:
#      Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0     0.550     0.425   0.155        0.9175          0.2775          0.2430
# 1     0.500     0.400   0.120        0.6160          0.2610          0.1430
# 2     0.620     0.480   0.155        1.2555          0.5270          0.3740
# 3     0.220     0.165   0.055        0.0545          0.0215          0.0120
# 4     0.645     0.500   0.175        1.5105          0.6735          0.3755
# ..      ...       ...     ...           ...             ...             ...
# 831   0.610     0.475   0.140        1.1330          0.5275          0.2355
# 832   0.410     0.325   0.120        0.3745          0.1580          0.0810
# 833   0.445     0.345   0.105        0.4090          0.1675          0.1015
# 834   0.540     0.435   0.180        0.9960          0.3835          0.2260
# 835   0.250     0.175   0.060        0.0635          0.0275          0.0080
#
#      Shell_weight  Sex_I  Sex_M
# ...

# %%
test_predict=lr.predict(df_test2)

# %%
test_predict
# Out:
# array([11.89320531,  8.34654401, 11.16937114,  5.96698102, 11.83493842,
#        11.54492903,  8.16800691,  9.34021257,  7.36684836, 11.84893119,
#         7.61522123,  6.20563417,  8.26278054,  9.07438594,  6.09789706,
#        10.22356139,  7.88014131, 12.50308121, 11.49371919,  7.25622702,
#         6.73220933,  6.51173287,  7.87396759,  7.74667056,  9.21083863,
#        10.67817855,  6.73595575, 12.89027136,  9.05266706, 10.68777797,
#         7.92708295,  5.63474541, 10.88813458, 14.37778666,  6.84735792,
#         8.79155142,  7.72332089, 10.29160637,  7.45103189, 11.57312854,
#        10.81672473,  9.04056443, 10.62184465, 10.96524395, 11.72056457,
#         8.90058512,  9.62175877, 11.34154353,  9.90357162,  7.08277621,
#        10.90215405,  6.88194771,  8.64483237, 12.74247521,  9.03327729,
#         8.32116373,  7.15438588,  7.65884155,  6.92290948,  6.64536708,
#        10.28088167,  9.45828691, 10.45526843,  7.34870798,  7.12841855,
# ...

# %%
df_test3 = pd.read_csv(r"C:\Users\abhin\machine learning\term 1 project\ablone\abalone_test.csv")
df_test3
# Out:
#        Id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0     668   M   0.550     0.425   0.155        0.9175          0.2775
# 1    1580   I   0.500     0.400   0.120        0.6160          0.2610
# 2    3784   M   0.620     0.480   0.155        1.2555          0.5270
# 3     463   I   0.220     0.165   0.055        0.0545          0.0215
# 4    2615   M   0.645     0.500   0.175        1.5105          0.6735
# ..    ...  ..     ...       ...     ...           ...             ...
# 831   575   F   0.610     0.475   0.140        1.1330          0.5275
# 832  3231   M   0.410     0.325   0.120        0.3745          0.1580
# 833  1084   I   0.445     0.345   0.105        0.4090          0.1675
# 834   290   M   0.540     0.435   0.180        0.9960          0.3835
# 835  2713   I   0.250     0.175   0.060        0.0635          0.0275
#
#      Viscera_weight  Shell_weight
# 0            0.2430        0.3350
# 1            0.1430        0.1935
# ...

# %%
df_test3=df_test3['Id']

# %%
final_op=(list(zip(df_test3,test_predict)))

# %%
final_op
# Out:
# [(668, 11.89320530932308),
#  (1580, 8.346544013312645),
#  (3784, 11.169371142993345),
#  (463, 5.966981017542639),
#  (2615, 11.834938421754394),
#  (1399, 11.544929025901114),
#  (2054, 8.168006910911648),
#  (2058, 9.340212569423398),
#  (217, 7.366848359216572),
#  (1931, 11.848931188349455),
#  (1571, 7.615221225280335),
#  (3379, 6.205634166589601),
#  (569, 8.262780537655562),
#  (3155, 9.07438593824941),
#  (1430, 6.09789706184181),
#  (991, 10.223561391637864),
#  (4120, 7.880141307424685),
#  (2211, 12.503081208248158),
#  (1675, 11.493719189173433),
#  (2640, 7.25622701860339),
#  (45, 6.732209327051873),
#  (1432, 6.511732868104991),
#  (4122, 7.873967593973554),
#  (2439, 7.746670562127698),
#  (576, 9.210838628136557),
#  (87, 10.67817855238296),
#  (2381, 6.735955754241363),
#  (3242, 12.890271356802234),
#  (1328, 9.052667062088503),
#  (748, 10.687777968321495),
#  (3178, 7.92708294687855),
#  (3902, 5.634745413083899),
#  (189, 10.888134579638523),
# ...

# %%
final_op_df = pd.DataFrame(final_op)

# %%
final_op_df.to_csv('submission1.csv', index=False, header=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 final_op_df.to_csv('submission1.csv', index=False, header=False)
#
# File ~\anaconda31\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...
